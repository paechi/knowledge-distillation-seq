# %%
cd drive/MyDrive/Colab\ Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !git clone https://github.com/OpenNMT/OpenNMT-py
# Out:
# fatal: destination path 'OpenNMT-py' already exists and is not an empty directory.

# %%
cd OpenNMT-py/
# Out:
# /content/drive/MyDrive/Colab Notebooks/OpenNMT-py

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/drive/MyDrive/Colab%20Notebooks/OpenNMT-py
# ...
#      |████████████████████████████████| 81kB 7.6MB/s
# ...
#      |████████████████████████████████| 748.8MB 22kB/s
# ...
#      |████████████████████████████████| 81kB 11.1MB/s
# ...
#      |████████████████████████████████| 102kB 11.9MB/s
# ...
#      |████████████████████████████████| 61kB 7.2MB/s
# ...
#      |████████████████████████████████| 645kB 49.0MB/s
# ...
#      |████████████████████████████████| 14.3MB 188kB/s
# ...
#      |████████████████████████████████| 1.2MB 49.6MB/s
# ...
# ERROR: torchvision 0.10.0+cu102 has requirement torch==1.9.0, but you'll have torch 1.6.0 which is incompatible.
# ...
#   Found existing installation: tqdm 4.41.1
#     Uninstalling tqdm-4.41.1:
#       Successfully uninstalled tqdm-4.41.1
#   Found existing installation: torch 1.9.0+cu102
#     Uninstalling torch-1.9.0+cu102:
#       Successfully uninstalled torch-1.9.0+cu102
#   Found existing installation: torchtext 0.10.0
#     Uninstalling torchtext-0.10.0:
# ...

# %%
# !nvidia-smi
# Out:
# Fri Jul  2 16:29:29 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   61C    P0    31W / 250W |      2MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !rm -rf th-en/run

# %%
# !onmt_build_vocab -config th_en.yaml
# Out:
# Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2021-07-07 11:28:21,908 INFO] Counter vocab from 5000 samples.
# [2021-07-07 11:28:21,908 INFO] Build vocab on 5000 transformed examples/corpus.
# [2021-07-07 11:28:21,916 INFO] corpus_1's transforms: TransformPipe()
# [2021-07-07 11:28:22,118 INFO] Counters src:8934
# [2021-07-07 11:28:22,118 INFO] Counters tgt:8733

# %%
# !onmt_train -config th_en.yaml
# Out:
# [2021-07-07 11:42:48,834 INFO] Missing transforms field for corpus_1 data, set to default: [].
# [2021-07-07 11:42:48,834 WARNING] Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2021-07-07 11:42:48,835 INFO] Missing transforms field for valid data, set to default: [].
# [2021-07-07 11:42:48,835 INFO] Parsed 2 corpora from -data.
# [2021-07-07 11:42:48,835 INFO] Get special vocabs from Transforms: {'src': set(), 'tgt': set()}.
# [2021-07-07 11:42:48,835 INFO] Loading vocab from text file...
# [2021-07-07 11:42:48,835 INFO] Loading src vocabulary from th-en/run/example.vocab.src
# [2021-07-07 11:42:48,855 INFO] Loaded src vocab has 8934 tokens.
# [2021-07-07 11:42:48,859 INFO] Loading tgt vocabulary from th-en/run/example.vocab.tgt
# [2021-07-07 11:42:48,877 INFO] Loaded tgt vocab has 8733 tokens.
# [2021-07-07 11:42:48,881 INFO] Building fields with vocab in counters...
# [2021-07-07 11:42:48,910 INFO]  * tgt vocab size: 25000.
# ...

# %%
# !onmt_translate -model th-en/run/model_step_10000.pt -src th-en/test.th.sp -output th-en/pred.txt -gpu 0 -verbose -beam_size 1
# Out:
# Streaming output truncated to the last 5000 lines.
# SENT 1333: ['▁แต่', '▁สิ่งที่', '▁สําคัญ', '▁คือ', '▁ความ', '▁คิดสร้างสรรค์', '▁ที่', '▁มัน', '▁ให้', '▁แรงบันดาล', '▁ใจ', '▁ท่ามกลาง', 'วัฒนธรรม', '▁ทาง', '▁อินเทอร์เน็ต', '▁แบ', '▁บ', 'กี๊', '▁ก', '▁ๆ']
# PRED 1333: ▁But ▁what ' s ▁important ▁is ▁creativity ▁that <unk> s ▁in ▁the ▁Internet , ▁the ▁Internet , ▁the <unk> <unk> .
# PRED SCORE: -18.0927
#
# [2021-07-07 11:40:32,606 INFO]
# SENT 1334: ['▁เมื่อ', '▁พูด', '▁ถึง', '▁วิกฤต', '▁สิ่งแวดล้อม', '▁ฉัน', '▁คิด', '▁ว่า', '▁ปัญหา', '▁ใหญ่', '▁นี้', '▁มี', '▁มาก', 'ว่า', '▁สิบ', '▁ปี', '▁แล้ว', '▁นั่น', '▁คือ', '▁เด็ก', '▁ถูก', '▁ขัง', '▁ไว้', '▁ใน', '▁ห้อง', '▁ติด', '▁กับ', '▁เครื่อง', '▁', 'PC', '▁ไม่ได้', '▁ออกไป', '▁ข้าง', '▁นอก']
# PRED 1334: ▁When ▁it ▁comes ▁to ▁environmental ▁environmental ▁crisis , ▁I ▁think , ▁that ' s ▁10 ▁years ▁ago , ▁that ' s ▁a ▁child ▁in ▁the ▁room ▁with ▁a <unk> <unk> , ▁not ▁out ▁of ▁the ▁outside .
# PRED SCORE: -35.5904
#
# ...

# %%
# !perl tools/multi-bleu.perl th-en/test.en.sp < th-en/pred.txt
# Out:
# BLEU = 13.35, 43.8/17.9/8.9/4.6 (BP=1.000, ratio=1.019, hyp_len=49282, ref_len=48361)
